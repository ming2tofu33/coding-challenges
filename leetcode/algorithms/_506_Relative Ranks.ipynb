# %% [markdown]
# # `506_Relative Ranks`

# %%
pass

# %%
score = [10,3,8,9,4]
ranked_score = []
for idx, n in enumerate(score, start=1):
    ranked_score.append((n, idx))
    
print(ranked_score)
ranked_score.sort(reverse=True)
print(ranked_score)
# Out:
# [(10, 1), (3, 2), (8, 3), (9, 4), (4, 5)]
# [(10, 1), (9, 4), (8, 3), (4, 5), (3, 2)]
