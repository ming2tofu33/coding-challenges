# %% [markdown]
# # `182_Duplicate Emails`

# %%
-- Write your MySQL query statement below
SELECT
    email as Email
FROM Person
GROUP BY email
HAVING COUNT(*) > 1

# %%
-- Write your PostgreSQL query statement below
SELECT
    email as Email
FROM Person
GROUP BY email
HAVING COUNT(*) > 1

# %%
import pandas as pd

def duplicate_emails(person: pd.DataFrame) -> pd.DataFrame:
    duplicate = person[person.duplicated(subset=['email'])]
    return duplicate[['email']].drop_duplicates(subset=['email'])
